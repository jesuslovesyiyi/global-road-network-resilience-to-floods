# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
import os
import sys
import networkx as nx
import osmnx as ox
import pandas as pd
import pickle
from tqdm import tqdm
import warnings; warnings.simplefilter('ignore')

pd.options.display.max_columns = None
pd.options.display.max_rows = 30

# %%
# Initiate a list of 10 different flood return periods
RP_lst = [5, 10, 20, 50, 75, 100, 200, 250, 500, 1000]

# Directory where graphs with flood inundation levels attached to the nodes and edges
flooded_graphs_2616_dir = 'L:/yiyi/2616_flooded_graphs_drive_servce_no_res/'

# %%
# Iterate through 10 flood return periods
for rp in RP_lst:
    # Print return period
    print('RP=' + str(rp))
    
    # Iterate through graphs in the directory
    for flooded_graph_file in os.listdir(flooded_graphs_2616_dir):
        # Find network id
        net_id = int(flooded_graph_file[11:][:-13])
        print('net_id='+ str(net_id))
        
        # Load graph
        G_flooded =  pickle.load(open(flooded_graphs_2616_dir + flooded_graph_file, 'rb'))
        # Make a copy of the graph
        G_disrupted = G_flooded.copy()

        # Delete nodes with flood inundation greater than 30cm or 0.3m
        for node_id, node_data in G_flooded.nodes.data():
            if node_data['FUP_' + str(rp)] >= 0.3:
                G_disrupted.remove_node(node_id)

        print('removed: '+ str(G_disrupted.number_of_nodes()) + ' from ' + str(G_flooded.number_of_nodes()))
        # Add original/dry speed
        try:
            G_disrupted_speed = ox.speed.add_edge_speeds(G_disrupted)
            print('finished adding ori speed')
        except:
            print('CANNOT add ori speed')
            continue
        # Alter the maximum travel speed for edges
        # Reference paper:
        # Pregnolato, Maria, et al. "The impact of flooding on road transport: A depth-disruption function."
        # Transportation research part D: transport and environment 55 (2017): 67-81.
        for start_id, end_id, edge_data in G_disrupted_speed.edges.data():
            edge_water_depth_mm = max(G_disrupted_speed.nodes[start_id]['FUP_'+str(rp)], G_disrupted_speed.nodes[end_id]['FUP_'+str(rp)])
            theoretical_speed = 86.9448 - (0.5529*edge_water_depth_mm) + (0.0009*edge_water_depth_mm*edge_water_depth_mm)
            designed_speed = edge_data['speed_kph']
            G_disrupted_speed[start_id][end_id][0]['speed_kph'] = min(theoretical_speed, designed_speed)
        try:
            G_disrupted_speed_time = ox.speed.add_edge_travel_times(G_disrupted_speed)
            print('finished changing speed')
        except:
            print('CANNOT disrupt speed and time')
        # Save disrupted graphs    
        with open('L:/yiyi/2616_disrupted_graphs/FUP_' + str(rp) + '/G_' + str(net_id) + '_disrupted_FUP_' + str(rp) + '.pk', 'wb') as handle:
            pickle.dump(G_disrupted_speed_time, handle, protocol=2)
# Out:
# RP=5
# net_id=1000
# removed: 8368 from 8411
# finished adding ori speed
# finished changing speed
# net_id=1001
# removed: 5468 from 5626
# finished adding ori speed
# finished changing speed
# net_id=1003
# removed: 4454 from 4555
# finished adding ori speed
# finished changing speed
# net_id=1005
# removed: 5224 from 5314
# finished adding ori speed
# finished changing speed
# net_id=1006
# removed: 17895 from 18266
# finished adding ori speed
# finished changing speed
# net_id=1007
# removed: 5338 from 5371
# finished adding ori speed
# finished changing speed
# net_id=1008
# removed: 46986 from 47581
# finished adding ori speed
# finished changing speed
# net_id=1009
# removed: 28510 from 28788
# finished adding ori speed
# finished changing speed
# net_id=100
# removed: 21564 from 28730
# finished adding ori speed
# finished changing speed
# net_id=1010
# removed: 4799 from 4951
# finished adding ori speed
# finished changing speed
# net_id=1011
# removed: 2484 from 2499
# finished adding ori speed
# finished changing speed
# net_id=1012
# removed: 22515 from 22860
# finished adding ori speed
# finished changing speed
# net_id=1015
# removed: 1113 from 1220
# finished adding ori speed
# finished changing speed
# net_id=1016
# removed: 1864 from 1988
# finished adding ori speed
# finished changing speed
# net_id=1017
# removed: 1328 from 1377
# finished adding ori speed
# finished changing speed
# net_id=1018
# removed: 4049 from 4134
# finished adding ori speed
# finished changing speed
# net_id=1019
# removed: 292781 from 297933
# finished adding ori speed
# finished changing speed
# net_id=101
# removed: 5941 from 5949
# finished adding ori speed
# finished changing speed
# net_id=1022
# removed: 3128 from 3498
# finished adding ori speed
# finished changing speed
# net_id=1025
# removed: 5146 from 5316
# finished adding ori speed
# finished changing speed
# net_id=1026
# removed: 1714 from 1806
# finished adding ori speed
# finished changing speed
# net_id=1028
# removed: 19168 from 19414
# finished adding ori speed
# finished changing speed
# net_id=1029
# removed: 9775 from 10215
# finished adding ori speed
# finished changing speed
# net_id=102
# removed: 13992 from 14213
# finished adding ori speed
# finished changing speed
# net_id=1030
# removed: 8635 from 8802
# finished adding ori speed
# finished changing speed
# net_id=1031
# removed: 11605 from 11739
# finished adding ori speed
# finished changing speed
# net_id=1032
# removed: 4157 from 4218
# finished adding ori speed
# finished changing speed
# net_id=1034
# removed: 2550 from 2608
# finished adding ori speed
# finished changing speed
# net_id=1036
# removed: 2812 from 2838
# finished adding ori speed
# finished changing speed
# net_id=1037
# removed: 3621 from 3815
# finished adding ori speed
# finished changing speed
# net_id=1038
# removed: 5298 from 5313
# finished adding ori speed
# finished changing speed
# net_id=1039
# removed: 3106 from 3125
# finished adding ori speed
# finished changing speed
# net_id=103
# removed: 10312 from 10390
# finished adding ori speed
# finished changing speed
# net_id=1040
# removed: 2634 from 2741
# finished adding ori speed
# finished changing speed
# net_id=1044
# removed: 21663 from 21877
# finished adding ori speed
# finished changing speed
# net_id=1045
# removed: 2234 from 2234
# finished adding ori speed
# finished changing speed
# net_id=1049
# removed: 2879 from 2895
# finished adding ori speed
# finished changing speed
# net_id=104
# removed: 7761 from 7879
# finished adding ori speed
# finished changing speed
# net_id=1051
# removed: 4649 from 4808
# finished adding ori speed
# finished changing speed
# net_id=1052
# removed: 2738 from 2747
# finished adding ori speed
# finished changing speed
# net_id=1053
# removed: 6583 from 6737
# finished adding ori speed
# finished changing speed
# net_id=1054
# removed: 6651 from 6830
# finished adding ori speed
# finished changing speed
# net_id=1055
# removed: 7183 from 7434
# finished adding ori speed
# finished changing speed
# net_id=1056
# removed: 7666 from 7878
# finished adding ori speed
# finished changing speed
# net_id=1057
# removed: 3796 from 3840
# finished adding ori speed
# finished changing speed
# net_id=1058
# removed: 5082 from 5311
# finished adding ori speed
# finished changing speed
# net_id=1059
# removed: 25664 from 25950
# finished adding ori speed
# finished changing speed
# net_id=105
# removed: 5364 from 5387
# finished adding ori speed
# finished changing speed
# net_id=1060
# removed: 39565 from 40695
# finished adding ori speed
# finished changing speed
# net_id=1061
# removed: 40537 from 41676
# finished adding ori speed
# finished changing speed
# net_id=1062
# removed: 17147 from 17498
# finished adding ori speed
# finished changing speed
# net_id=1065
# removed: 16505 from 17199
# finished adding ori speed
# finished changing speed
# net_id=1066
# removed: 16301 from 16591
# finished adding ori speed
# finished changing speed
# net_id=1068
# removed: 2325 from 2480
# finished adding ori speed
# finished changing speed
# net_id=1069
# removed: 509470 from 524427
# finished adding ori speed
# finished changing speed
# net_id=106
# removed: 1237 from 1240
# finished adding ori speed
# finished changing speed
# net_id=1071
# removed: 6294 from 6335
# finished adding ori speed
# finished changing speed
# net_id=1072
# removed: 549 from 555
# finished adding ori speed
# finished changing speed
# net_id=1074
# removed: 89486 from 90654
# finished adding ori speed
# finished changing speed
# net_id=1076
# removed: 2794 from 2875
# finished adding ori speed
# finished changing speed
# net_id=1077
# removed: 553581 from 563440
# finished adding ori speed
# finished changing speed
# net_id=1078
# removed: 10358 from 10390
# finished adding ori speed
# finished changing speed
# net_id=1079
# removed: 6009 from 6013
# finished adding ori speed
# finished changing speed
# net_id=107
# removed: 7479 from 7487
# finished adding ori speed
# finished changing speed
# net_id=1081
# removed: 2388 from 2459
# finished adding ori speed
# finished changing speed
# net_id=1082
# removed: 2320 from 2349
# finished adding ori speed
# finished changing speed
# net_id=1084
# removed: 2591 from 2629
# finished adding ori speed
# finished changing speed
# net_id=1085
# removed: 2247 from 2295
# finished adding ori speed
# finished changing speed
# net_id=1086
# removed: 24251 from 24497
# finished adding ori speed
# finished changing speed
# net_id=1087
# removed: 3587 from 3610
# finished adding ori speed
# finished changing speed
# net_id=1088
# removed: 852 from 870
# finished adding ori speed
# finished changing speed
# net_id=1089
# removed: 8911 from 9206
# finished adding ori speed
# finished changing speed
# net_id=108
# removed: 7894 from 8309
# finished adding ori speed
# finished changing speed
# net_id=1092
# removed: 2069 from 2121
# finished adding ori speed
# finished changing speed
# net_id=1095
# removed: 9131 from 9233
# finished adding ori speed
# finished changing speed
# net_id=1097
# removed: 1774 from 1800
# finished adding ori speed
# finished changing speed
# net_id=1099
# removed: 6162 from 6168
# finished adding ori speed
# finished changing speed
# net_id=109
# removed: 28168 from 28264
# finished adding ori speed
# finished changing speed
# net_id=10
# removed: 13017 from 13119
# finished adding ori speed
# finished changing speed
# net_id=1100
# removed: 40786 from 41299
# finished adding ori speed
# finished changing speed
# net_id=1101
# removed: 1142 from 1176
# finished adding ori speed
# finished changing speed
# net_id=1102
# removed: 2791 from 2815
# finished adding ori speed
# finished changing speed
# net_id=1105
# removed: 9141 from 9180
# finished adding ori speed
# finished changing speed
# net_id=1108
# removed: 20776 from 21241
# finished adding ori speed
# finished changing speed
# net_id=1109
# removed: 1652 from 1653
# finished adding ori speed
# finished changing speed
# net_id=110
# removed: 6219 from 6234
# finished adding ori speed
# finished changing speed
# net_id=1111
# removed: 22724 from 23014
# finished adding ori speed
# finished changing speed
# net_id=1112
# removed: 3860 from 4098
# finished adding ori speed
# finished changing speed
# net_id=1113
# removed: 6278 from 6313
# finished adding ori speed
# finished changing speed
# net_id=1115
# removed: 5265 from 5283
# finished adding ori speed
# finished changing speed
# net_id=1116
# removed: 2622 from 2633
# finished adding ori speed
# finished changing speed
# net_id=1117
# removed: 4477 from 4557
# finished adding ori speed
# finished changing speed
# net_id=1119
# removed: 3212 from 3293
# finished adding ori speed
# finished changing speed
# net_id=111
# removed: 101725 from 101894
# finished adding ori speed
# finished changing speed
# net_id=1121
# removed: 69256 from 69758
# finished adding ori speed
# finished changing speed
# net_id=1122
# removed: 5589 from 5619
# finished adding ori speed
# finished changing speed
# net_id=1123
# removed: 8383 from 8692
# finished adding ori speed
# finished changing speed
# net_id=1125
# removed: 17824 from 17855
# finished adding ori speed
# finished changing speed
# net_id=1126
# removed: 2702 from 2715
# finished adding ori speed
# finished changing speed
# net_id=1127
# removed: 2344 from 2422
# CANNOT add ori speed
# net_id=1128
# removed: 3780 from 4089
# finished adding ori speed
# finished changing speed
# net_id=1129
# removed: 3162 from 3173
# finished adding ori speed
# finished changing speed
# net_id=112
# removed: 8359 from 8388
# finished adding ori speed
# finished changing speed
# net_id=1130
# removed: 74955 from 75677
# finished adding ori speed
# finished changing speed
# net_id=1131
# removed: 1577 from 1708
# finished adding ori speed
# finished changing speed
# net_id=1132
# removed: 1934 from 2037
# finished adding ori speed
# finished changing speed
# net_id=1133
# removed: 4064 from 4108
# finished adding ori speed
# finished changing speed
# net_id=1136
# removed: 1681 from 1748
# finished adding ori speed
# finished changing speed
# net_id=1137
# removed: 932 from 934
# finished adding ori speed
# finished changing speed
# net_id=1138
# removed: 649 from 651
# finished adding ori speed
# finished changing speed
# net_id=113
# removed: 5221 from 5239
# finished adding ori speed
# finished changing speed
# net_id=1141
# removed: 15048 from 15133
# finished adding ori speed
# finished changing speed
# net_id=1142
# removed: 183239 from 185844
# finished adding ori speed
# finished changing speed
# net_id=1143
# removed: 3535 from 3536
# finished adding ori speed
# finished changing speed
# net_id=1144
# removed: 1672 from 1725
# finished adding ori speed
# finished changing speed
# net_id=1145
# removed: 43411 from 44425
# finished adding ori speed
# finished changing speed
# net_id=1146
# removed: 2845 from 2884
# finished adding ori speed
# finished changing speed
# net_id=1149
# removed: 4590 from 4680
# finished adding ori speed
# finished changing speed
# net_id=114
# removed: 2166 from 2173
# finished adding ori speed
# finished changing speed
# net_id=1150
# removed: 9157 from 9231
# finished adding ori speed
# finished changing speed
# net_id=1155
# removed: 136651 from 137698
# finished adding ori speed
# finished changing speed
# net_id=1156
# removed: 6038 from 6084
# finished adding ori speed
# finished changing speed
# net_id=1157
# removed: 2313 from 2324
# finished adding ori speed
# finished changing speed
# net_id=1159
# removed: 11088 from 11199
# finished adding ori speed
# finished changing speed
# net_id=115
# removed: 10815 from 10855
# finished adding ori speed
# finished changing speed
# net_id=1160
# removed: 61766 from 62158
# finished adding ori speed
# finished changing speed
# net_id=1161
# removed: 1429 from 1450
# finished adding ori speed
# finished changing speed
# net_id=1162
# removed: 24993 from 25205
# finished adding ori speed
# finished changing speed
# net_id=1164
# removed: 6468 from 6509
# finished adding ori speed
# finished changing speed
# net_id=1167
# removed: 2276 from 2283
# finished adding ori speed
# finished changing speed
# net_id=1168
# removed: 5319 from 5526
# finished adding ori speed
# finished changing speed
# net_id=1169
# removed: 4000 from 4051
# finished adding ori speed
# finished changing speed
# net_id=116
# removed: 28288 from 28377
# finished adding ori speed
# finished changing speed
# net_id=1170
# removed: 1619 from 1629
# finished adding ori speed
# finished changing speed
# net_id=1171
# removed: 8526 from 8615
# finished adding ori speed
# finished changing speed
# net_id=1172
# removed: 3860 from 3962
# finished adding ori speed
# finished changing speed
# net_id=1173
# removed: 20903 from 20946
# finished adding ori speed
# finished changing speed
# net_id=1176
# removed: 3975 from 4091
# finished adding ori speed
# finished changing speed
# net_id=1177
# removed: 1784 from 1810
# finished adding ori speed
# finished changing speed
# net_id=1179
# removed: 6221 from 6275
# finished adding ori speed
# finished changing speed
# net_id=117
# removed: 4590 from 4595
# finished adding ori speed
# finished changing speed
# net_id=1180
# removed: 7327 from 7391
# finished adding ori speed
# finished changing speed
# net_id=1181
# removed: 3398 from 3400
# finished adding ori speed
# finished changing speed
# net_id=1182
# removed: 18446 from 18774
# finished adding ori speed
# finished changing speed
# net_id=1183
# removed: 2524 from 2540
# finished adding ori speed
# finished changing speed
# net_id=1184
# removed: 2102 from 2114
# finished adding ori speed
# finished changing speed
# net_id=1185
# removed: 24299 from 24426
# finished adding ori speed
# finished changing speed
# net_id=1188
# removed: 84255 from 84276
# finished adding ori speed
# finished changing speed
# net_id=1189
# removed: 6367 from 6538
# finished adding ori speed
# finished changing speed
# net_id=118
# removed: 1829 from 1829
# finished adding ori speed
# finished changing speed
# net_id=1190
# removed: 17871 from 18070
# finished adding ori speed
# finished changing speed
# net_id=1191
# removed: 4026 from 4057
# finished adding ori speed
# finished changing speed
# net_id=1192
# removed: 3894 from 4327
# finished adding ori speed
# finished changing speed
# net_id=1193
# removed: 2808 from 3013
# finished adding ori speed
# finished changing speed
# net_id=1196
# removed: 4301 from 4317
# finished adding ori speed
# finished changing speed
# net_id=1198
# removed: 19609 from 19830
# finished adding ori speed
# finished changing speed
# net_id=1199
# removed: 1100 from 1118
# finished adding ori speed
# finished changing speed
# net_id=119
# removed: 14084 from 14229
# finished adding ori speed
# finished changing speed
# net_id=11
# removed: 7202 from 7238
# finished adding ori speed
# finished changing speed
# net_id=1201
# removed: 3552 from 3643
# finished adding ori speed
# finished changing speed
# net_id=1202
# removed: 2283 from 2327
# finished adding ori speed
# finished changing speed
# net_id=1203
# removed: 85425 from 85935
# finished adding ori speed
# finished changing speed
# net_id=1204
# removed: 5260 from 5303
# finished adding ori speed
# finished changing speed
# net_id=1205
# removed: 71139 from 71606
# finished adding ori speed
# finished changing speed
# net_id=1206
# removed: 2144 from 2588
# finished adding ori speed
# finished changing speed
# net_id=1207
# removed: 5122 from 5206
# finished adding ori speed
# finished changing speed
# net_id=1208
# removed: 1313 from 1315
# finished adding ori speed
# finished changing speed
# net_id=1209
# removed: 221379 from 224188
# finished adding ori speed
# finished changing speed
# net_id=120
# removed: 5621 from 5676
# finished adding ori speed
# finished changing speed
# net_id=1210
# removed: 124545 from 130440
# finished adding ori speed
# finished changing speed
# net_id=1211
# removed: 3114 from 3134
# finished adding ori speed
# finished changing speed
# net_id=1212
# removed: 9311 from 9436
# finished adding ori speed
# finished changing speed
# net_id=1213
# removed: 2900 from 2956
# finished adding ori speed
# finished changing speed
# net_id=1214
# removed: 2842 from 2865
# finished adding ori speed
# finished changing speed
# net_id=1216
# removed: 7231 from 7329
# finished adding ori speed
# finished changing speed
# net_id=1217
# removed: 6046 from 6151
# finished adding ori speed
# finished changing speed
# net_id=1219
# removed: 27243 from 27586
# finished adding ori speed
# finished changing speed
# net_id=121
# removed: 3097 from 3129
# finished adding ori speed
# finished changing speed
# net_id=1220
# removed: 73610 from 73992
# finished adding ori speed
# finished changing speed
# net_id=1222
# removed: 1686 from 1783
# finished adding ori speed
# finished changing speed
# net_id=1223
# removed: 4492 from 5287
# finished adding ori speed
# finished changing speed
# net_id=1224
# removed: 5624 from 5961
# finished adding ori speed
# finished changing speed
# net_id=1225
# removed: 700 from 701
# finished adding ori speed
# finished changing speed
# net_id=1226
# removed: 588 from 597
# finished adding ori speed
# finished changing speed
# net_id=1227
# removed: 7064 from 7191
# finished adding ori speed
# finished changing speed
# net_id=1228
# removed: 3490 from 3560
# finished adding ori speed
# finished changing speed
# net_id=1229
# removed: 2066 from 2099
# finished adding ori speed
# finished changing speed
# net_id=122
# removed: 6239 from 6289
# finished adding ori speed
# finished changing speed
# net_id=1232
# removed: 2188 from 2220
# finished adding ori speed
# finished changing speed
# net_id=1233
# removed: 1862 from 1906
# finished adding ori speed
# finished changing speed
# net_id=1235
# removed: 95250 from 96875
# finished adding ori speed
# finished changing speed
# net_id=1236
# removed: 6312 from 6447
# finished adding ori speed
# finished changing speed
# net_id=1237
# removed: 39842 from 40315
# finished adding ori speed
# finished changing speed
# net_id=1238
# removed: 14825 from 14976
# finished adding ori speed
# finished changing speed
# net_id=123
# removed: 43595 from 43663
# finished adding ori speed
# finished changing speed
# net_id=1241
# removed: 5705 from 6436
# finished adding ori speed
# finished changing speed
# net_id=1242
# removed: 1967 from 1969
# finished adding ori speed
# finished changing speed
# net_id=1244
# removed: 3853 from 3869
# finished adding ori speed
# finished changing speed
# net_id=1245
# removed: 2819 from 2888
# finished adding ori speed
# finished changing speed
# net_id=1247
# removed: 6011 from 6049
# finished adding ori speed
# finished changing speed
# net_id=1248
# removed: 11533 from 11626
# finished adding ori speed
# finished changing speed
# net_id=1249
# removed: 1028 from 1034
# finished adding ori speed
# finished changing speed
# net_id=124
# removed: 6424 from 6460
# finished adding ori speed
# finished changing speed
# net_id=1250
# removed: 4586 from 4677
# finished adding ori speed
# finished changing speed
# net_id=1253
# removed: 36777 from 36936
# finished adding ori speed
# finished changing speed
# net_id=1258
# removed: 3240 from 3388
# finished adding ori speed
# finished changing speed
# net_id=1259
# removed: 4214 from 4332
# finished adding ori speed
# finished changing speed
# net_id=125
# removed: 5612 from 5681
# finished adding ori speed
# finished changing speed
# net_id=1260
# removed: 4831 from 4872
# finished adding ori speed
# finished changing speed
# net_id=1261
# removed: 4011 from 4027
# finished adding ori speed
# finished changing speed
# net_id=1262
# removed: 2454 from 2461
# finished adding ori speed
# finished changing speed
# net_id=1264
# removed: 22734 from 22936
# finished adding ori speed
# finished changing speed
# net_id=1265
# removed: 2417 from 2499
# finished adding ori speed
# finished changing speed
# net_id=1266
# removed: 13806 from 13927
# finished adding ori speed
# finished changing speed
# net_id=1267
# removed: 3118 from 3119
# finished adding ori speed
# finished changing speed
# net_id=1269
# removed: 3769 from 3785
# finished adding ori speed
# finished changing speed
# net_id=126
# removed: 5695 from 5695
# finished adding ori speed
# finished changing speed
# net_id=1270
# removed: 3691 from 3696
# finished adding ori speed
# finished changing speed
# net_id=1271
# removed: 4033 from 4268
# finished adding ori speed
# finished changing speed
# net_id=1274
# removed: 102840 from 104867
# finished adding ori speed
# finished changing speed
# net_id=1277
# removed: 1033 from 1138
# finished adding ori speed
# finished changing speed
# net_id=1278
# removed: 21541 from 21697
# finished adding ori speed
# finished changing speed
# net_id=1279
# removed: 1775 from 1810
# finished adding ori speed
# finished changing speed
# net_id=127
# removed: 452656 from 457814
# finished adding ori speed
# finished changing speed
# net_id=1280
# removed: 11812 from 11901
# finished adding ori speed
# finished changing speed
# net_id=1281
# removed: 1676 from 1696
# finished adding ori speed
# finished changing speed
# net_id=1283
# removed: 4138 from 4169
# finished adding ori speed
# finished changing speed
# net_id=1285
# removed: 1115 from 1118
# finished adding ori speed
# finished changing speed
# net_id=1289
# removed: 5914 from 5982
# finished adding ori speed
# finished changing speed
# net_id=128
# removed: 3511 from 3529
# finished adding ori speed
# finished changing speed
# net_id=1292
# removed: 17369 from 17442
# finished adding ori speed
# finished changing speed
# net_id=1295
# removed: 153187 from 154443
# finished adding ori speed
# finished changing speed
# net_id=1296
# removed: 10639 from 10799
# finished adding ori speed
# finished changing speed
# net_id=1298
# removed: 2500 from 2542
# finished adding ori speed
# finished changing speed
# net_id=1299
# removed: 36466 from 37256
# finished adding ori speed
# finished changing speed
# net_id=129
# removed: 40645 from 41456
# finished adding ori speed
# finished changing speed
# net_id=12
# removed: 1903 from 1903
# finished adding ori speed
# finished changing speed
# net_id=1300
# removed: 3267 from 3505
# finished adding ori speed
# finished changing speed
# net_id=1301
# removed: 5037 from 5044
# finished adding ori speed
# finished changing speed
# net_id=1303
# removed: 4611 from 4628
# finished adding ori speed
# finished changing speed
# net_id=1306
# removed: 6501 from 6565
# finished adding ori speed
# finished changing speed
# net_id=1309
# removed: 5045 from 5071
# finished adding ori speed
# finished changing speed
# net_id=130
# removed: 3829 from 3832
# finished adding ori speed
# finished changing speed
# net_id=1310
# removed: 39125 from 39317
# finished adding ori speed
# finished changing speed
# net_id=1311
# removed: 8052 from 8108
# finished adding ori speed
# finished changing speed
# net_id=1312
# removed: 15836 from 16007
# finished adding ori speed
# finished changing speed
# net_id=1313
# removed: 5659 from 5680
# finished adding ori speed
# finished changing speed
# net_id=1314
# removed: 8960 from 9080
# finished adding ori speed
# finished changing speed
# net_id=1316
# removed: 1274 from 1280
# finished adding ori speed
# finished changing speed
# net_id=1317
# removed: 1379 from 1967
# finished adding ori speed
# finished changing speed
# net_id=1318
# removed: 11276 from 11554
# finished adding ori speed
# finished changing speed
# net_id=1319
# removed: 2621 from 2621
# finished adding ori speed
# finished changing speed
# net_id=131
# removed: 23726 from 24089
# finished adding ori speed
# finished changing speed
# net_id=1320
# removed: 2125 from 2208
# finished adding ori speed
# finished changing speed
# net_id=1321
# removed: 2700 from 2773
# finished adding ori speed
# finished changing speed
# net_id=1322
# removed: 1952 from 2088
# finished adding ori speed
# finished changing speed
# net_id=1323
# removed: 3942 from 3955
# finished adding ori speed
# finished changing speed
# net_id=1325
# removed: 5148 from 5168
# finished adding ori speed
# finished changing speed
# net_id=1327
# removed: 35484 from 36003
# finished adding ori speed
# finished changing speed
# net_id=1328
# removed: 6553 from 6613
# finished adding ori speed
# finished changing speed
# net_id=1329
# removed: 1342 from 1378
# finished adding ori speed
# finished changing speed
# net_id=132
# removed: 7009 from 7035
# finished adding ori speed
# finished changing speed
# net_id=1330
# removed: 181507 from 184796
# finished adding ori speed
# finished changing speed
# net_id=1331
# removed: 2336 from 2347
# finished adding ori speed
# finished changing speed
# net_id=1332
# removed: 3002 from 3036
# finished adding ori speed
# finished changing speed
# net_id=1333
# removed: 5473 from 5517
# finished adding ori speed
# finished changing speed
# net_id=1334
# removed: 2223 from 2233
# finished adding ori speed
# finished changing speed
# net_id=1336
# removed: 3358 from 3363
# finished adding ori speed
# finished changing speed
# net_id=1337
# removed: 12691 from 13349
# finished adding ori speed
# finished changing speed
# net_id=1339
# removed: 97755 from 98806
# finished adding ori speed
# finished changing speed
# net_id=133
# removed: 7488 from 7686
# finished adding ori speed
# finished changing speed
# net_id=1341
# removed: 41776 from 42976
# finished adding ori speed
# finished changing speed
# net_id=1343
# removed: 3792 from 3794
# finished adding ori speed
# finished changing speed
# net_id=1344
# removed: 1893 from 1950
# finished adding ori speed
# finished changing speed
# net_id=1346
# removed: 3255 from 3326
# finished adding ori speed
# finished changing speed
# net_id=1347
# removed: 36897 from 36984
# finished adding ori speed
# finished changing speed
# net_id=1348
# removed: 3852 from 3956
# finished adding ori speed
# finished changing speed
# net_id=1349
# removed: 4042 from 4076
# finished adding ori speed
# finished changing speed
# net_id=134
# removed: 7567 from 7587
# finished adding ori speed
# finished changing speed
# net_id=1350
# removed: 4069 from 4087
# finished adding ori speed
# finished changing speed
# net_id=1351
# removed: 3461 from 3714
# finished adding ori speed
# finished changing speed
# net_id=1352
# removed: 10047 from 10412
# finished adding ori speed
# finished changing speed
# net_id=1353
# removed: 2767 from 2770
# finished adding ori speed
# finished changing speed
# net_id=1354
# removed: 16176 from 16391
# finished adding ori speed
# finished changing speed
# net_id=1355
# removed: 3748 from 3756
# finished adding ori speed
# finished changing speed
# net_id=1356
# removed: 1886 from 1939
# finished adding ori speed
# finished changing speed
# net_id=1357
# removed: 9068 from 9218
# finished adding ori speed
# finished changing speed
# net_id=1358
# removed: 2047 from 2064
# finished adding ori speed
# finished changing speed
# net_id=1359
# removed: 1868 from 1882
# finished adding ori speed
# finished changing speed
# net_id=135
# removed: 44488 from 45288
# finished adding ori speed
# finished changing speed
# net_id=1360
# removed: 4099 from 4253
# finished adding ori speed
# finished changing speed
# net_id=1361
# removed: 90148 from 90540
# finished adding ori speed
# finished changing speed
# net_id=1365
# removed: 4015 from 4057
# finished adding ori speed
# finished changing speed
# net_id=1366
# removed: 112476 from 113099
# finished adding ori speed
# finished changing speed
# net_id=1367
# removed: 3801 from 3862
# finished adding ori speed
# finished changing speed
# net_id=1368
# removed: 3674 from 3692
# finished adding ori speed
# finished changing speed
# net_id=1369
# removed: 3488 from 3671
# finished adding ori speed
# finished changing speed
# net_id=136
# removed: 6576 from 6579
# finished adding ori speed
# finished changing speed
# net_id=1370
# removed: 2198 from 2218
# finished adding ori speed
# finished changing speed
# net_id=1371
# removed: 5641 from 5772
# finished adding ori speed
# finished changing speed
# net_id=1372
# removed: 9181 from 9568
# finished adding ori speed
# finished changing speed
# net_id=1373
# removed: 5818 from 5831
# finished adding ori speed
# finished changing speed
# net_id=1374
# removed: 3916 from 4305
# finished adding ori speed
# finished changing speed
# net_id=1375
# removed: 5828 from 5875
# finished adding ori speed
# finished changing speed
# net_id=1376
# removed: 3516 from 3694
# finished adding ori speed
# finished changing speed
# net_id=1378
# removed: 32438 from 33004
# finished adding ori speed
# finished changing speed
# net_id=1379
# removed: 7447 from 7465
# finished adding ori speed
# finished changing speed
# net_id=137
# removed: 12934 from 12965
# finished adding ori speed
# finished changing speed
# net_id=1380
# removed: 7398 from 9487
# finished adding ori speed
# finished changing speed
# net_id=1381
# removed: 978 from 987
# finished adding ori speed
# finished changing speed
# net_id=1382
# removed: 692 from 692
# finished adding ori speed
# finished changing speed
# net_id=1383
# removed: 4628 from 4653
# finished adding ori speed
# finished changing speed
# net_id=1385
# removed: 8345 from 8408
# finished adding ori speed
# finished changing speed
# net_id=1386
# removed: 15455 from 15803
# finished adding ori speed
# finished changing speed
# net_id=1387
# removed: 2653 from 2715
# finished adding ori speed
# finished changing speed
# net_id=1388
# removed: 32536 from 32782
# finished adding ori speed
# finished changing speed
# net_id=1389
# removed: 3088 from 3097
# finished adding ori speed
# finished changing speed
# net_id=138
# removed: 2920 from 2949
# finished adding ori speed
# finished changing speed
# net_id=1392
# removed: 7206 from 7274
# finished adding ori speed
# finished changing speed
# net_id=1393
# removed: 1905 from 1907
# finished adding ori speed
# finished changing speed
# net_id=1394
# removed: 135726 from 137418
# finished adding ori speed
# finished changing speed
# net_id=1395
# removed: 5758 from 5792
# finished adding ori speed
# finished changing speed
# net_id=1396
# removed: 1393 from 1394
# finished adding ori speed
# finished changing speed
# net_id=1397
# removed: 1261 from 1334
# finished adding ori speed
# finished changing speed
# net_id=1398
# removed: 2800 from 2806
# finished adding ori speed
# finished changing speed
# net_id=1399
# removed: 10724 from 10783
# finished adding ori speed
# finished changing speed
# net_id=139
# removed: 1968 from 2035
# finished adding ori speed
# finished changing speed
# net_id=13
# removed: 5692 from 5696
# finished adding ori speed
# finished changing speed
# net_id=1400
# removed: 3772 from 3832
# finished adding ori speed
# finished changing speed
# net_id=1401
# removed: 5678 from 5802
# finished adding ori speed
# finished changing speed
# net_id=1402
# removed: 4355 from 4366
# finished adding ori speed
# finished changing speed
# net_id=1403
# removed: 59167 from 59774
# finished adding ori speed
# finished changing speed
# net_id=1405
# removed: 12704 from 12732
# finished adding ori speed
# finished changing speed
# net_id=1406
# removed: 9296 from 9390
# finished adding ori speed
# finished changing speed
# net_id=1407
# removed: 909 from 933
# finished adding ori speed
# finished changing speed
# net_id=1408
# removed: 3087 from 3193
# finished adding ori speed
# finished changing speed
# net_id=1409
# removed: 10145 from 10226
# finished adding ori speed
# finished changing speed
# net_id=140
# removed: 33674 from 33991
# finished adding ori speed
# finished changing speed
# net_id=1410
# removed: 22988 from 23139
# finished adding ori speed
# finished changing speed
# net_id=1411
# removed: 12224 from 12224
# finished adding ori speed
# finished changing speed
# net_id=1412
# removed: 69908 from 70673
# finished adding ori speed
# finished changing speed
# net_id=1413
# removed: 11379 from 11862
# finished adding ori speed
# finished changing speed
# net_id=1414
# removed: 30888 from 31310
# finished adding ori speed
# finished changing speed
# net_id=1415
# removed: 5225 from 5232
# finished adding ori speed
# finished changing speed
# net_id=1416
# removed: 8068 from 8076
# finished adding ori speed
# finished changing speed
# net_id=1417
# removed: 3662 from 3688
# finished adding ori speed
# finished changing speed
# net_id=1419
# removed: 3576 from 3588
# finished adding ori speed
# finished changing speed
# net_id=141
# removed: 13287 from 13348
# finished adding ori speed
# finished changing speed
# net_id=1422
# removed: 3342 from 3409
# finished adding ori speed
# finished changing speed
# net_id=1423
# removed: 2602 from 2626
# finished adding ori speed
# finished changing speed
# net_id=1426
# removed: 18031 from 18151
# finished adding ori speed
# finished changing speed
# net_id=1427
# removed: 749 from 753
# finished adding ori speed
# finished changing speed
# net_id=1428
# removed: 3548 from 3565
# finished adding ori speed
# finished changing speed
# net_id=1429
# removed: 7541 from 7596
# finished adding ori speed
# finished changing speed
# net_id=142
# removed: 84767 from 85651
# finished adding ori speed
# finished changing speed
# net_id=1430
# removed: 2039 from 2062
# finished adding ori speed
# finished changing speed
# net_id=1431
# removed: 1676 from 1687
# finished adding ori speed
# finished changing speed
# net_id=1432
# removed: 13181 from 13291
# finished adding ori speed
# finished changing speed
# net_id=1433
# removed: 1599 from 1607
# finished adding ori speed
# finished changing speed
# net_id=1434
# removed: 1751 from 1754
# finished adding ori speed
# finished changing speed
# net_id=1435
# removed: 2954 from 2964
# finished adding ori speed
# finished changing speed
# net_id=1437
# removed: 3045 from 3173
# finished adding ori speed
# finished changing speed
# net_id=1438
# removed: 55554 from 55736
# finished adding ori speed
# finished changing speed
# net_id=1439
# removed: 2030 from 2263
# finished adding ori speed
# finished changing speed
# net_id=143
# removed: 16920 from 17054
# finished adding ori speed
# finished changing speed
# net_id=1440
# removed: 2628 from 2656
# finished adding ori speed
# finished changing speed
# net_id=1441
# removed: 46208 from 46688
# finished adding ori speed
# finished changing speed
# net_id=1442
# removed: 8030 from 8105
# finished adding ori speed
# finished changing speed
# net_id=1443
# removed: 101857 from 102833
# finished adding ori speed
# finished changing speed
# net_id=1444
# removed: 18107 from 18127
# finished adding ori speed
# finished changing speed
# net_id=1445
# removed: 3569 from 3584
# finished adding ori speed
# finished changing speed
# net_id=1446
# removed: 12415 from 12665
# finished adding ori speed
# finished changing speed
# net_id=1447
# removed: 3576 from 3669
# finished adding ori speed
# finished changing speed
# net_id=1448
# removed: 4116 from 4161
# finished adding ori speed
# finished changing speed
# net_id=1449
# removed: 16895 from 16995
# finished adding ori speed
# finished changing speed
# net_id=144
# removed: 4351 from 4382
# finished adding ori speed
# finished changing speed
# net_id=1451
# removed: 2252 from 2263
# finished adding ori speed
# finished changing speed
# net_id=1453
# removed: 19064 from 19306
# finished adding ori speed
# finished changing speed
# net_id=1454
# removed: 1806 from 1814
# finished adding ori speed
# finished changing speed
# net_id=1455
# removed: 7928 from 7958
# finished adding ori speed
# finished changing speed
# net_id=1456
# removed: 4058 from 4060
# finished adding ori speed
# finished changing speed
# net_id=1459
# removed: 1256 from 1325
# finished adding ori speed
# finished changing speed
# net_id=145
# removed: 2939 from 2942
# finished adding ori speed
# finished changing speed
# net_id=1460
# removed: 7156 from 7193
# finished adding ori speed
# finished changing speed
# net_id=1461
# removed: 1613 from 1700
# finished adding ori speed
# finished changing speed
# net_id=1462
# removed: 1456 from 1528
# finished adding ori speed
# finished changing speed
# net_id=1464
# removed: 3751 from 3756
# finished adding ori speed
# finished changing speed
# net_id=1465
# removed: 17082 from 17250
# finished adding ori speed
# finished changing speed
# net_id=1466
# removed: 6126 from 6192
# finished adding ori speed
# finished changing speed
# net_id=1467
# removed: 7336 from 7574
# finished adding ori speed
# finished changing speed
# net_id=146
# removed: 2262 from 2264
# finished adding ori speed
# finished changing speed
# net_id=1470
# removed: 164326 from 166459
# finished adding ori speed
# finished changing speed
# net_id=1471
# removed: 9966 from 10353
# finished adding ori speed
# finished changing speed
# net_id=1472
# removed: 3690 from 3691
# finished adding ori speed
# finished changing speed
# net_id=1473
# removed: 3015 from 3015
# finished adding ori speed
# finished changing speed
# net_id=1474
# removed: 924 from 929
# finished adding ori speed
# finished changing speed
# net_id=1475
# removed: 88967 from 90312
# finished adding ori speed
# finished changing speed
# net_id=1476
# removed: 2449 from 2451
# finished adding ori speed
# finished changing speed
# net_id=1477
# removed: 1014 from 1014
# finished adding ori speed
# finished changing speed
# net_id=1478
# removed: 1976 from 1980
# finished adding ori speed
# finished changing speed
# net_id=1479
# removed: 66867 from 67799
# finished adding ori speed
# finished changing speed
# net_id=147
# removed: 4105 from 4246
# finished adding ori speed
# finished changing speed
# net_id=1480
# removed: 4460 from 4569
# finished adding ori speed
# finished changing speed
# net_id=1484
# removed: 15416 from 15478
# finished adding ori speed
# finished changing speed
# net_id=1485
# removed: 5942 from 5962
# finished adding ori speed
# finished changing speed
# net_id=1486
# removed: 1962 from 2014
# finished adding ori speed
# finished changing speed
# net_id=148
# removed: 18698 from 18764
# finished adding ori speed
# finished changing speed
# net_id=1490
# removed: 3994 from 3999
# finished adding ori speed
# finished changing speed
# net_id=1491
# removed: 4126 from 4160
# finished adding ori speed
# finished changing speed
# net_id=1493
# removed: 26070 from 26121
# finished adding ori speed
# finished changing speed
# net_id=1495
# removed: 8636 from 8687
# finished adding ori speed
# finished changing speed
# net_id=1496
# removed: 62602 from 63405
# finished adding ori speed
# finished changing speed
# net_id=1497
# removed: 6615 from 6664
# finished adding ori speed
# finished changing speed
# net_id=1498
# removed: 10207 from 10251
# finished adding ori speed
# finished changing speed
# net_id=1499
# removed: 2700 from 2735
# finished adding ori speed
# finished changing speed
# net_id=149
# removed: 53969 from 54559
# finished adding ori speed
# finished changing speed
# net_id=14
# removed: 7471 from 7525
# finished adding ori speed
# finished changing speed
# net_id=1500
# removed: 3279 from 3303
# finished adding ori speed
# finished changing speed
# net_id=1501
# removed: 98608 from 101382
# finished adding ori speed
# finished changing speed
# net_id=1503
# removed: 22053 from 22769
# finished adding ori speed
# finished changing speed
# net_id=1504
# removed: 1612 from 1638
# finished adding ori speed
# finished changing speed
# net_id=1505
# removed: 568 from 574
# finished adding ori speed
# finished changing speed
# net_id=1507
# removed: 11783 from 11931
# finished adding ori speed
# finished changing speed
# net_id=1508
# removed: 18085 from 18473
# finished adding ori speed
# finished changing speed
# net_id=1509
# removed: 398 from 406
# finished adding ori speed
# finished changing speed
# net_id=150
# removed: 3128 from 3135
# finished adding ori speed
# finished changing speed
# net_id=1510
# removed: 2019 from 2042
# finished adding ori speed
# finished changing speed
# net_id=1511
# removed: 2930 from 2985
# finished adding ori speed
# finished changing speed
# net_id=1513
# removed: 15229 from 15455
# finished adding ori speed
# finished changing speed
# net_id=1514
# removed: 4298 from 4305
# finished adding ori speed
# finished changing speed
# net_id=1516
# removed: 16069 from 16492
# finished adding ori speed
# finished changing speed
# net_id=1517
# removed: 5560 from 5562
# finished adding ori speed
# finished changing speed
# net_id=1518
# removed: 944 from 945
# finished adding ori speed
# finished changing speed
# net_id=1519
# removed: 5262 from 5285
# finished adding ori speed
# finished changing speed
# net_id=151
# removed: 12229 from 12254
# finished adding ori speed
# finished changing speed
# net_id=1521
# removed: 3127 from 3246
# finished adding ori speed
# finished changing speed
# net_id=1522
# removed: 7481 from 7520
# finished adding ori speed
# finished changing speed
# net_id=1523
# removed: 3155 from 3259
# finished adding ori speed
# finished changing speed
# net_id=1524
# removed: 3614 from 3616
# finished adding ori speed
# finished changing speed
# net_id=1525
# removed: 5396 from 5433
# finished adding ori speed
# finished changing speed
# net_id=1526
# removed: 1591 from 1682
# finished adding ori speed
# finished changing speed
# net_id=1527
# removed: 18195 from 18433
# finished adding ori speed
# finished changing speed
# net_id=1529
# removed: 5929 from 5931
# finished adding ori speed
# finished changing speed
# net_id=152
# removed: 27998 from 29355
# finished adding ori speed
# finished changing speed
# net_id=1531
# removed: 46036 from 47578
# finished adding ori speed
# finished changing speed
# net_id=1532
# removed: 4183 from 4189
# finished adding ori speed
# finished changing speed
# net_id=1533
# removed: 24204 from 24337
# finished adding ori speed
# finished changing speed
# net_id=1535
# removed: 2124 from 2161
# finished adding ori speed
# finished changing speed
# net_id=1536
# removed: 4382 from 4462
# finished adding ori speed
# finished changing speed
# net_id=1537
# removed: 1899 from 1937
# finished adding ori speed
# finished changing speed
# net_id=1538
# removed: 24420 from 24556
# finished adding ori speed
# finished changing speed
# net_id=1539
# removed: 6955 from 7032
# finished adding ori speed
# finished changing speed
# net_id=153
# removed: 37392 from 37763
# finished adding ori speed
# finished changing speed
# net_id=1540
# removed: 2079 from 2108
# finished adding ori speed
# finished changing speed
# net_id=1541
# removed: 55846 from 56684
# finished adding ori speed
# finished changing speed
# net_id=1542
# removed: 7328 from 7369
# finished adding ori speed
# finished changing speed
# net_id=1544
# removed: 3245 from 3444
# finished adding ori speed
# finished changing speed
# net_id=1545
# removed: 2572 from 2685
# finished adding ori speed
# finished changing speed
# net_id=1547
# removed: 967 from 984
# finished adding ori speed
# finished changing speed
# net_id=1548
# removed: 4092 from 4204
# finished adding ori speed
# finished changing speed
# net_id=1549
# removed: 695 from 728
# finished adding ori speed
# finished changing speed
# net_id=154
# removed: 2815 from 2817
# finished adding ori speed
# finished changing speed
# net_id=1550
# removed: 1163 from 1183
# finished adding ori speed
# finished changing speed
# net_id=1552
# removed: 877 from 900
# finished adding ori speed
# finished changing speed
# net_id=1554
# removed: 67512 from 68783
# finished adding ori speed
# finished changing speed
# net_id=1555
# removed: 9907 from 10028
# finished adding ori speed
# finished changing speed
# net_id=1556
# removed: 3516 from 3563
# finished adding ori speed
# finished changing speed
# net_id=1557
# removed: 2115 from 2149
# finished adding ori speed
# finished changing speed
# net_id=1558
# removed: 3832 from 3884
# finished adding ori speed
# finished changing speed
# net_id=1559
# removed: 11342 from 11512
# finished adding ori speed
# finished changing speed
# net_id=155
# removed: 3573 from 3610
# finished adding ori speed
# finished changing speed
# net_id=1561
# removed: 2256 from 2288
# finished adding ori speed
# finished changing speed
# net_id=1563
# removed: 1626 from 1809
# finished adding ori speed
# finished changing speed
# net_id=1565
# removed: 3255 from 3344
# finished adding ori speed
# finished changing speed
# net_id=1566
# removed: 48735 from 49164
# finished adding ori speed
# finished changing speed
# net_id=156
# removed: 3852 from 3854
# finished adding ori speed
# finished changing speed
# net_id=1570
# removed: 3279 from 3281
# finished adding ori speed
# finished changing speed
# net_id=1572
# removed: 29645 from 29728
# finished adding ori speed
# finished changing speed
# net_id=1573
# removed: 1105 from 1165
# finished adding ori speed
# finished changing speed
# net_id=1574
# removed: 32336 from 32752
# finished adding ori speed
# finished changing speed
# net_id=1575
# removed: 685 from 711
# finished adding ori speed
# finished changing speed
# net_id=1576
# removed: 8011 from 8025
# finished adding ori speed
# finished changing speed
# net_id=1577
# removed: 6257 from 6258
# finished adding ori speed
# finished changing speed
# net_id=1578
# removed: 3286 from 3322
# finished adding ori speed
# finished changing speed
# net_id=1579
# removed: 1144 from 1209
# finished adding ori speed
# finished changing speed
# net_id=157
# removed: 10154 from 10195
# finished adding ori speed
# finished changing speed
# net_id=1580
# removed: 1754 from 1862
# finished adding ori speed
# finished changing speed
# net_id=1581
# removed: 3490 from 3520
# finished adding ori speed
# finished changing speed
# net_id=1582
# removed: 3214 from 3230
# finished adding ori speed
# finished changing speed
# net_id=1583
# removed: 10085 from 10186
# finished adding ori speed
# finished changing speed
# net_id=1584
# removed: 3992 from 3999
# finished adding ori speed
# finished changing speed
# net_id=1585
# removed: 10419 from 10509
# finished adding ori speed
# finished changing speed
# net_id=1587
# removed: 3683 from 3735
# finished adding ori speed
# finished changing speed
# net_id=1588
# removed: 13008 from 13616
# finished adding ori speed
# finished changing speed
# net_id=1589
# removed: 20787 from 20801
# finished adding ori speed
# finished changing speed
# net_id=158
# removed: 7001 from 7103
# finished adding ori speed
# finished changing speed
# net_id=1590
# removed: 3046 from 3057
# finished adding ori speed
# finished changing speed
# net_id=1591
# removed: 7604 from 7604
# finished adding ori speed
# finished changing speed
# net_id=1592
# removed: 4240 from 4460
# finished adding ori speed
# finished changing speed
# net_id=1593
# removed: 56295 from 58064
# finished adding ori speed
# finished changing speed
# net_id=1594
# removed: 1117 from 1117
# finished adding ori speed
# finished changing speed
# net_id=1595
# removed: 1449 from 1466
# finished adding ori speed
# finished changing speed
# net_id=1596
# removed: 6720 from 6788
# finished adding ori speed
# finished changing speed
# net_id=1597
# removed: 7755 from 7781
# finished adding ori speed
# finished changing speed
# net_id=1598
# removed: 2334 from 2351
# finished adding ori speed
# finished changing speed
# net_id=1599
# removed: 1621 from 1733
# finished adding ori speed
# finished changing speed
# net_id=159
# removed: 3128 from 3174
# finished adding ori speed
# finished changing speed
# net_id=15
# removed: 6148 from 6224
# finished adding ori speed
# finished changing speed
# net_id=1600
# removed: 2291 from 2348
# finished adding ori speed
# finished changing speed
# net_id=1601
# removed: 3270 from 3286
# finished adding ori speed
# finished changing speed
# net_id=1602
# removed: 2611 from 2616
# finished adding ori speed
# finished changing speed
# net_id=1603
# removed: 1401 from 1401
# finished adding ori speed
# finished changing speed
# net_id=1604
# removed: 1312 from 1322
# finished adding ori speed
# finished changing speed
# net_id=1605
# removed: 3805 from 3821
# finished adding ori speed
# finished changing speed
# net_id=1606
# removed: 15029 from 15098
# finished adding ori speed
# finished changing speed
# net_id=1607
# removed: 1638 from 1642
# finished adding ori speed
# finished changing speed
# net_id=1608
# removed: 4817 from 5009
# finished adding ori speed
# finished changing speed
# net_id=1609
# removed: 10309 from 10439
# finished adding ori speed
# finished changing speed
# net_id=160
# removed: 3888 from 3907
# finished adding ori speed
# finished changing speed
# net_id=1610
# removed: 15455 from 15518
# finished adding ori speed
# finished changing speed
# net_id=1611
# removed: 90073 from 90160
# finished adding ori speed
# finished changing speed
# net_id=1612
# removed: 46563 from 47045
# finished adding ori speed
# finished changing speed
# net_id=1613
# removed: 2989 from 3015
# finished adding ori speed
# finished changing speed
# net_id=1614
# removed: 2461 from 2465
# finished adding ori speed
# finished changing speed
# net_id=1616
# removed: 4704 from 4796
# finished adding ori speed
# finished changing speed
# net_id=1618
# removed: 12888 from 13613
# finished adding ori speed
# finished changing speed
# net_id=161
# removed: 11620 from 11694
# finished adding ori speed
# finished changing speed
# net_id=1620
# removed: 709 from 767
# CANNOT add ori speed
# net_id=1621
# removed: 909 from 958
# finished adding ori speed
# finished changing speed
# net_id=1622
# removed: 12221 from 12224
# finished adding ori speed
# finished changing speed
# net_id=1625
# removed: 3183 from 3185
# finished adding ori speed
# finished changing speed
# net_id=1626
# removed: 5817 from 5935
# finished adding ori speed
# finished changing speed
# net_id=1627
# removed: 1234 from 1237
# finished adding ori speed
# finished changing speed
# net_id=1628
# removed: 87817 from 90252
# finished adding ori speed
# finished changing speed
# net_id=1629
# removed: 2080 from 2184
# finished adding ori speed
# finished changing speed
# net_id=162
# removed: 18593 from 18876
# finished adding ori speed
# finished changing speed
# net_id=1631
# removed: 4489 from 4512
# finished adding ori speed
# finished changing speed
# net_id=1633
# removed: 104905 from 107086
# finished adding ori speed
# finished changing speed
# net_id=1636
# removed: 816 from 817
# finished adding ori speed
# finished changing speed
# net_id=1637
# removed: 31999 from 33140
# finished adding ori speed
# finished changing speed
# net_id=1638
# removed: 8336 from 8376
# finished adding ori speed
# finished changing speed
# net_id=1639
# removed: 3294 from 3302
# finished adding ori speed
# finished changing speed
# net_id=163
# removed: 1745 from 1745
# finished adding ori speed
# finished changing speed
# net_id=1640
# removed: 7791 from 7805
# finished adding ori speed
# finished changing speed
# net_id=1641
# removed: 1935 from 1940
# finished adding ori speed
# finished changing speed
# net_id=1642
# removed: 9983 from 9991
# finished adding ori speed
# finished changing speed
# net_id=1643
# removed: 74437 from 77028
# finished adding ori speed
# finished changing speed
# net_id=1644
# removed: 1486 from 1488
# finished adding ori speed
# finished changing speed
# net_id=1645
# removed: 4561 from 4595
# finished adding ori speed
# finished changing speed
# net_id=1646
# removed: 4964 from 5043
# finished adding ori speed
# finished changing speed
# net_id=1647
# removed: 3855 from 3863
# finished adding ori speed
# finished changing speed
# net_id=1648
# removed: 7748 from 7803
# finished adding ori speed
# finished changing speed
# net_id=1649
# removed: 3291 from 3501
# finished adding ori speed
# finished changing speed
# net_id=164
# removed: 8406 from 8502
# finished adding ori speed
# finished changing speed
# net_id=1650
# removed: 4638 from 5272
# finished adding ori speed
# finished changing speed
# net_id=1652
# removed: 107627 from 108635
# finished adding ori speed
# ...
# finished adding ori speed
# finished changing speed
# net_id=793
# removed: 3926 from 4404
# finished adding ori speed
# finished changing speed
# net_id=794
# removed: 12139 from 12811
# finished adding ori speed
# finished changing speed
# net_id=795
# removed: 69846 from 87532
# finished adding ori speed
# finished changing speed
# net_id=796
# removed: 967 from 1168
# finished adding ori speed
# finished changing speed
# net_id=797
# removed: 11660 from 13126
# finished adding ori speed
# finished changing speed
# net_id=798
# removed: 2794 from 3722
# finished adding ori speed
# finished changing speed
# net_id=799
# removed: 6773 from 7333
# finished adding ori speed
# finished changing speed
# net_id=79
# removed: 5076 from 5462
# finished adding ori speed
# finished changing speed
# net_id=7
# removed: 3185 from 3889
# finished adding ori speed
# finished changing speed
# net_id=800
# removed: 2782 from 4459
# finished adding ori speed
# finished changing speed
# net_id=801
# removed: 2384 from 3417
# finished adding ori speed
# finished changing speed
# net_id=802
# removed: 4433 from 4992
# finished adding ori speed
# finished changing speed
# net_id=803
# removed: 46621 from 61170
# finished adding ori speed
# finished changing speed
# net_id=804
# removed: 1680 from 2794
# finished adding ori speed
# finished changing speed
# net_id=805
# removed: 1235 from 1553
# finished adding ori speed
# finished changing speed
# net_id=806
# removed: 1213 from 1373
# finished adding ori speed
# finished changing speed
# net_id=807
# removed: 1918 from 2021
# finished adding ori speed
# finished changing speed
# net_id=809
# removed: 1218 from 1604
# finished adding ori speed
# finished changing speed
# net_id=80
# removed: 15874 from 17034
# finished adding ori speed
# finished changing speed
# net_id=810
# removed: 11530 from 14003
# finished adding ori speed
# finished changing speed
# net_id=811
# removed: 14538 from 17610
# finished adding ori speed
# finished changing speed
# net_id=812
# removed: 5524 from 6043
# finished adding ori speed
# finished changing speed
# net_id=814
# removed: 5145 from 6013
# finished adding ori speed
# finished changing speed
# net_id=815
# removed: 28341 from 31892
# finished adding ori speed
# finished changing speed
# net_id=816
# removed: 3750 from 4307
# finished adding ori speed
# finished changing speed
# net_id=817
# removed: 2359 from 2599
# finished adding ori speed
# finished changing speed
# net_id=818
# removed: 841 from 858
# finished adding ori speed
# finished changing speed
# net_id=819
# removed: 1980 from 2263
# finished adding ori speed
# finished changing speed
# net_id=81
# removed: 5589 from 5919
# finished adding ori speed
# finished changing speed
# net_id=821
# removed: 1762 from 1900
# finished adding ori speed
# finished changing speed
# net_id=822
# removed: 6031 from 6306
# finished adding ori speed
# finished changing speed
# net_id=823
# removed: 16700 from 18409
# finished adding ori speed
# finished changing speed
# net_id=824
# removed: 1931 from 2901
# finished adding ori speed
# finished changing speed
# net_id=826
# removed: 3868 from 6677
# finished adding ori speed
# finished changing speed
# net_id=828
# removed: 751 from 912
# CANNOT add ori speed
# net_id=82
# removed: 4272 from 4397
# finished adding ori speed
# finished changing speed
# net_id=830
# removed: 1317 from 1640
# finished adding ori speed
# finished changing speed
# net_id=831
# removed: 3608 from 4277
# finished adding ori speed
# finished changing speed
# net_id=833
# removed: 5501 from 6357
# finished adding ori speed
# finished changing speed
# net_id=834
# removed: 6707 from 8225
# finished adding ori speed
# finished changing speed
# net_id=838
# removed: 5481 from 6157
# finished adding ori speed
# finished changing speed
# net_id=83
# removed: 3282 from 3505
# finished adding ori speed
# finished changing speed
# net_id=840
# removed: 6413 from 8422
# finished adding ori speed
# finished changing speed
# net_id=841
# removed: 3717 from 4269
# finished adding ori speed
# finished changing speed
# net_id=842
# removed: 4349 from 11104
# finished adding ori speed
# finished changing speed
# net_id=843
# removed: 6267 from 6907
# finished adding ori speed
# finished changing speed
# net_id=846
# removed: 1464 from 1585
# finished adding ori speed
# finished changing speed
# net_id=847
# removed: 8885 from 10818
# finished adding ori speed
# finished changing speed
# net_id=848
# removed: 1276 from 2303
# finished adding ori speed
# finished changing speed
# net_id=849
# removed: 19042 from 25373
# finished adding ori speed
# finished changing speed
# net_id=84
# removed: 5667 from 6153
# finished adding ori speed
# finished changing speed
# net_id=851
# removed: 9536 from 11528
# finished adding ori speed
# finished changing speed
# net_id=852
# removed: 39322 from 48954
# finished adding ori speed
# finished changing speed
# net_id=853
# removed: 1951 from 2701
# finished adding ori speed
# finished changing speed
# net_id=855
# removed: 5738 from 8855
# finished adding ori speed
# finished changing speed
# net_id=856
# removed: 3689 from 4194
# finished adding ori speed
# finished changing speed
# net_id=858
# removed: 2711 from 3628
# finished adding ori speed
# finished changing speed
# net_id=859
# removed: 1154 from 1749
# finished adding ori speed
# finished changing speed
# net_id=85
# removed: 3038 from 3106
# finished adding ori speed
# finished changing speed
# net_id=860
# removed: 6420 from 8163
# finished adding ori speed
# finished changing speed
# net_id=861
# removed: 2472 from 3191
# finished adding ori speed
# finished changing speed
# net_id=862
# removed: 8344 from 10490
# finished adding ori speed
# finished changing speed
# net_id=863
# removed: 6686 from 7611
# finished adding ori speed
# finished changing speed
# net_id=865
# removed: 8103 from 11743
# finished adding ori speed
# finished changing speed
# net_id=866
# removed: 17136 from 27831
# finished adding ori speed
# finished changing speed
# net_id=867
# removed: 2618 from 2929
# finished adding ori speed
# finished changing speed
# net_id=869
# removed: 3947 from 4591
# finished adding ori speed
# finished changing speed
# net_id=86
# removed: 46090 from 49618
# finished adding ori speed
# finished changing speed
# net_id=870
# removed: 1081 from 1579
# finished adding ori speed
# finished changing speed
# net_id=871
# removed: 9997 from 11515
# finished adding ori speed
# finished changing speed
# net_id=872
# removed: 333 from 399
# finished adding ori speed
# finished changing speed
# net_id=873
# removed: 4143 from 4211
# finished adding ori speed
# finished changing speed
# net_id=874
# removed: 3193 from 3977
# finished adding ori speed
# finished changing speed
# net_id=875
# removed: 19883 from 36822
# finished adding ori speed
# finished changing speed
# net_id=876
# removed: 3812 from 4172
# finished adding ori speed
# finished changing speed
# net_id=877
# removed: 927 from 1299
# finished adding ori speed
# finished changing speed
# net_id=87
# removed: 5419 from 5824
# finished adding ori speed
# finished changing speed
# net_id=880
# removed: 4442 from 5501
# finished adding ori speed
# finished changing speed
# net_id=881
# removed: 24432 from 28894
# finished adding ori speed
# finished changing speed
# net_id=883
# removed: 5354 from 5756
# finished adding ori speed
# finished changing speed
# net_id=884
# removed: 13343 from 14672
# finished adding ori speed
# finished changing speed
# net_id=885
# removed: 2602 from 3036
# finished adding ori speed
# finished changing speed
# net_id=886
# removed: 3868 from 5091
# finished adding ori speed
# finished changing speed
# net_id=887
# removed: 5363 from 6596
# finished adding ori speed
# finished changing speed
# net_id=889
# removed: 3005 from 3982
# finished adding ori speed
# finished changing speed
# net_id=88
# removed: 15955 from 16619
# finished adding ori speed
# finished changing speed
# net_id=890
# removed: 8539 from 9096
# finished adding ori speed
# finished changing speed
# net_id=892
# removed: 4071 from 6486
# finished adding ori speed
# finished changing speed
# net_id=893
# removed: 34500 from 40994
# finished adding ori speed
# finished changing speed
# net_id=895
# removed: 22623 from 25867
# finished adding ori speed
# finished changing speed
# net_id=897
# removed: 12945 from 17425
# finished adding ori speed
# finished changing speed
# net_id=898
# removed: 6121 from 6935
# finished adding ori speed
# finished changing speed
# net_id=899
# removed: 4020 from 4719
# finished adding ori speed
# finished changing speed
# net_id=89
# removed: 17378 from 18263
# finished adding ori speed
# finished changing speed
# net_id=8
# removed: 17292 from 18179
# finished adding ori speed
# finished changing speed
# net_id=900
# removed: 14310 from 15260
# finished adding ori speed
# finished changing speed
# net_id=902
# removed: 5637 from 6200
# finished adding ori speed
# finished changing speed
# net_id=903
# removed: 50536 from 66103
# finished adding ori speed
# finished changing speed
# net_id=904
# removed: 4407 from 4825
# finished adding ori speed
# finished changing speed
# net_id=905
# removed: 14463 from 17084
# finished adding ori speed
# finished changing speed
# net_id=906
# removed: 1923 from 2120
# finished adding ori speed
# finished changing speed
# net_id=907
# removed: 1065 from 1265
# finished adding ori speed
# finished changing speed
# net_id=908
# removed: 5463 from 10035
# finished adding ori speed
# finished changing speed
# net_id=909
# removed: 21898 from 23553
# finished adding ori speed
# finished changing speed
# net_id=90
# removed: 24452 from 27515
# finished adding ori speed
# finished changing speed
# net_id=910
# removed: 43361 from 52765
# finished adding ori speed
# finished changing speed
# net_id=911
# removed: 1872 from 3215
# finished adding ori speed
# finished changing speed
# net_id=913
# removed: 9656 from 12719
# finished adding ori speed
# finished changing speed
# net_id=914
# removed: 3039 from 3541
# finished adding ori speed
# finished changing speed
# net_id=915
# removed: 7728 from 9052
# finished adding ori speed
# finished changing speed
# net_id=916
# removed: 1545 from 1957
# finished adding ori speed
# finished changing speed
# net_id=918
# removed: 7765 from 10318
# finished adding ori speed
# finished changing speed
# net_id=919
# removed: 20683 from 24695
# finished adding ori speed
# finished changing speed
# net_id=91
# removed: 33929 from 35368
# finished adding ori speed
# finished changing speed
# net_id=920
# removed: 17685 from 22483
# finished adding ori speed
# finished changing speed
# net_id=921
# removed: 5686 from 6073
# finished adding ori speed
# finished changing speed
# net_id=922
# removed: 21199 from 24741
# finished adding ori speed
# finished changing speed
# net_id=923
# removed: 2082 from 2526
# finished adding ori speed
# finished changing speed
# net_id=924
# removed: 2593 from 2865
# finished adding ori speed
# finished changing speed
# net_id=925
# removed: 197087 from 274099
# finished adding ori speed
# finished changing speed
# net_id=926
# removed: 27068 from 33619
# finished adding ori speed
# finished changing speed
# net_id=927
# removed: 12544 from 14623
# finished adding ori speed
# finished changing speed
# net_id=928
# removed: 1338 from 4504
# finished adding ori speed
# finished changing speed
# net_id=929
# removed: 3652 from 4849
# finished adding ori speed
# finished changing speed
# net_id=930
# removed: 3679 from 4036
# finished adding ori speed
# finished changing speed
# net_id=931
# removed: 14145 from 16673
# finished adding ori speed
# finished changing speed
# net_id=932
# removed: 4168 from 5447
# finished adding ori speed
# finished changing speed
# net_id=933
# removed: 54504 from 57552
# finished adding ori speed
# finished changing speed
# net_id=934
# removed: 10901 from 14054
# finished adding ori speed
# finished changing speed
# net_id=935
# removed: 3355 from 3586
# finished adding ori speed
# finished changing speed
# net_id=936
# removed: 27232 from 30250
# finished adding ori speed
# finished changing speed
# net_id=937
# removed: 11158 from 12012
# finished adding ori speed
# finished changing speed
# net_id=938
# removed: 2763 from 3678
# finished adding ori speed
# finished changing speed
# net_id=939
# removed: 2325 from 2607
# finished adding ori speed
# finished changing speed
# net_id=93
# removed: 6776 from 7262
# finished adding ori speed
# finished changing speed
# net_id=940
# removed: 13821 from 17304
# finished adding ori speed
# finished changing speed
# net_id=941
# removed: 6344 from 7282
# finished adding ori speed
# finished changing speed
# net_id=944
# removed: 2363 from 3004
# finished adding ori speed
# finished changing speed
# net_id=945
# removed: 1238 from 2086
# finished adding ori speed
# finished changing speed
# net_id=946
# removed: 40848 from 45665
# finished adding ori speed
# finished changing speed
# net_id=949
# removed: 2053 from 2462
# finished adding ori speed
# finished changing speed
# net_id=94
# removed: 1751 from 1888
# finished adding ori speed
# finished changing speed
# net_id=950
# removed: 2829 from 3592
# finished adding ori speed
# finished changing speed
# net_id=952
# removed: 3844 from 4579
# finished adding ori speed
# finished changing speed
# net_id=953
# removed: 1378 from 1729
# finished adding ori speed
# finished changing speed
# net_id=954
# removed: 988 from 1683
# finished adding ori speed
# finished changing speed
# net_id=955
# removed: 61148 from 89485
# finished adding ori speed
# finished changing speed
# net_id=957
# removed: 7114 from 7640
# finished adding ori speed
# finished changing speed
# net_id=958
# removed: 308 from 364
# finished adding ori speed
# finished changing speed
# net_id=959
# removed: 4542 from 5591
# finished adding ori speed
# finished changing speed
# net_id=95
# removed: 16316 from 17757
# finished adding ori speed
# finished changing speed
# net_id=960
# removed: 7550 from 10708
# finished adding ori speed
# finished changing speed
# net_id=961
# removed: 50341 from 57342
# finished adding ori speed
# finished changing speed
# net_id=964
# removed: 10110 from 11440
# finished adding ori speed
# finished changing speed
# net_id=965
# removed: 12041 from 14287
# finished adding ori speed
# finished changing speed
# net_id=966
# removed: 4430 from 5047
# finished adding ori speed
# finished changing speed
# net_id=967
# removed: 141794 from 163684
# finished adding ori speed
# finished changing speed
# net_id=968
# removed: 17534 from 21273
# finished adding ori speed
# finished changing speed
# net_id=969
# removed: 16556 from 18590
# finished adding ori speed
# finished changing speed
# net_id=96
# removed: 42640 from 49175
# finished adding ori speed
# finished changing speed
# net_id=970
# removed: 837 from 1386
# finished adding ori speed
# finished changing speed
# net_id=971
# removed: 2821 from 3674
# finished adding ori speed
# finished changing speed
# net_id=972
# removed: 36591 from 42009
# finished adding ori speed
# finished changing speed
# net_id=973
# removed: 4205 from 4477
# finished adding ori speed
# finished changing speed
# net_id=974
# removed: 2489 from 3094
# finished adding ori speed
# finished changing speed
# net_id=975
# removed: 1723 from 2587
# finished adding ori speed
# finished changing speed
# net_id=976
# removed: 19150 from 28416
# finished adding ori speed
# finished changing speed
# net_id=977
# removed: 2158 from 2763
# finished adding ori speed
# finished changing speed
# net_id=978
# removed: 4531 from 5956
# finished adding ori speed
# finished changing speed
# net_id=980
# removed: 2743 from 4033
# finished adding ori speed
# finished changing speed
# net_id=981
# removed: 1868 from 2329
# finished adding ori speed
# finished changing speed
# net_id=982
# removed: 726 from 1024
# finished adding ori speed
# finished changing speed
# net_id=983
# removed: 1835 from 2457
# finished adding ori speed
# finished changing speed
# net_id=984
# removed: 4538 from 5101
# finished adding ori speed
# finished changing speed
# net_id=985
# removed: 3183 from 3528
# finished adding ori speed
# finished changing speed
# net_id=987
# removed: 1744 from 2103
# finished adding ori speed
# finished changing speed
# net_id=988
# removed: 1559 from 1814
# finished adding ori speed
# finished changing speed
# net_id=98
# removed: 6246 from 6475
# finished adding ori speed
# finished changing speed
# net_id=990
# removed: 2431 from 2657
# finished adding ori speed
# finished changing speed
# net_id=991
# removed: 2387 from 3461
# finished adding ori speed
# finished changing speed
# net_id=993
# removed: 20069 from 25119
# finished adding ori speed
# finished changing speed
# net_id=994
# removed: 1078 from 4235
# finished adding ori speed
# finished changing speed
# net_id=995
# removed: 19099 from 24323
# finished adding ori speed
# finished changing speed
# net_id=996
# removed: 4417 from 6378
# finished adding ori speed
# finished changing speed
# net_id=998
# removed: 785 from 903
# finished adding ori speed
# finished changing speed
# net_id=99
# removed: 6631 from 7430
# finished adding ori speed
# finished changing speed
# net_id=9
# removed: 3534 from 3879
# finished adding ori speed
# finished changing speed
